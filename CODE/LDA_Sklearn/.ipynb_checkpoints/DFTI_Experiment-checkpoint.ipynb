# %% [markdown]
# # DFTI Experiment
#
# The Boxcoxrox project utilizies the DFTI approach for categorizing reviews into high level groupings.  Unlike LDA, which uses product reviews  and an unsupervised learning approach, DFTI is a supervised learning approach that stars with a pre-set list of categories and key words.  The approach then counts the occurance of keywords in documents, and then uses an argmax approach to identify selected topics.  The DFTI approach is explained more fully in the DFTI notebook.  The purpose of this notebook is to estimate the accuracy of the approach.
#
# We begin by creating a list of know categories:

# %%
import pandas as pd
from matplotlib import pyplot as plt

def get_bcr_categories():
    cat_df = pd.read_csv('category.csv')
    categories = pd.DataFrame(cat_df.groupby('category').count()['asin'])
    categories.columns = ['count']
    #print(cat_counts)
    #categories = list(set(cat_df['category'].values))
    return categories


categories = get_bcr_categories()
categories
# Out:
#                          count
# category
# amphibians and reptiles   2708
# bird                      6223
# cat                      24710
# dog                      95392
# farm animals              3814
# fish                      8324
# other                    46134
# rabbits and rodents      11097

# %% [markdown]
# Next we create a sample of 20 products from each category.

# %%
def get_category_sample(category, n):
    prod_df = pd.read_csv("pet_products_all.csv")
    cat_df = pd.read_csv('category.csv')
    cat_df['bcr_category'] = cat_df['category']
    cat_df.drop(['category'], inplace=True, axis=1)
    cat_df = cat_df[cat_df['bcr_category']==category].sample(n)
    products = cat_df.merge(prod_df, on='asin')
    return products
    
get_category_sample("dog", 20)
# Out:
#           asin  category_id bcr_category  \
# 0   B00B0NRA6I            0          dog
# 1   B001HRIOSK            0          dog
# 2   B00BP2UJQW            0          dog
# 3   B004HQMXSK            0          dog
# 4   B00PXM1ONW            0          dog
# 5   B00HTUME1M            0          dog
# 6   B00986T30A            0          dog
# 7   B00SNZ4J1K            0          dog
# 8   B000Q3E3OU            0          dog
# 9   B006G4QJ4A            0          dog
# 10  B0035H3CJQ            0          dog
# 11  B01BPCLGZO            0          dog
# 12  B01DJOISVG            0          dog
# 13  B000R45YP0            0          dog
# 14  B00K7K0DAU            0          dog
# 15  B002TOOXAI            0          dog
# 16  B00IOFHYGQ            0          dog
# 17  B000GL6UIE            0          dog
# 18  B000WFRLYQ            0          dog
# 19  B00NYAWV0U            0          dog
#
#                                              category  \
# 0   Pet Supplies,Dogs,Collars, Harnesses & Leashes...
# 1      Pet Supplies,Dogs,Apparel & Accessories,Shirts
# 2   Pet Supplies,Dogs,Treats,Cookies, Biscuits & S...
# 3    Pet Supplies,Dogs,Apparel & Accessories,Sweaters
# 4           Pet Supplies,Dogs,Health Supplies,Wormers
# 5   Pet Supplies,Cats,Flea & Tick Control,Flea Col...
# 6   Pet Supplies,Dogs,Grooming,Shampoos & Conditio...
# 7                              Pet Supplies,Dogs,Toys
# 8   Pet Supplies,Dogs,Apparel & Accessories,Boots ...
# 9                              Pet Supplies,Dogs,Toys
# 10  Pet Supplies,Dogs,Collars, Harnesses & Leashes...
# 11  Pet Supplies,Dogs,Treats,Cookies, Biscuits & S...
# 12  Pet Supplies,Dogs,Treats,Cookies, Biscuits & S...
# 13  Pet Supplies,Dogs,Treats,Cookies, Biscuits & S...
# 14                        Pet Supplies,Cats,Memorials
# 15  Pet Supplies,Dogs,Carriers & Travel Products,C...
# 16   Pet Supplies,Dogs,Apparel & Accessories,Costumes
# 17  Pet Supplies,Dogs,Carriers & Travel Products,C...
# 18  Pet Supplies,Pet Content - Main,Pet Content - ...
# 19                                                NaN
#
#                                                 title  \
# 0   Freedom No-Pull Harness ONLY, Medium 1&quot;l Red
# 1         Soft, Colorful Dog Sweatshirt MEDIUM - PNK
# 2   Beefeaters 15 Count Redbarn Filled Bone, 6&quo...
# 3   East Side Collection Acrylic Present Dog Sweat...
# 4   Bayer Tapeworm Dewormer for Dogs, 4 weeks and ...
# 5   Fullsexy Flea and Tick Collar - Adjustable &am...
# 6   Nature's Specialties Almond Crisp Pet Shampoo,...
# 7   awtang Pet Touch Surprise Noise Dog Toy Giggle...
# 8                    XX-SMALL - PINK - Camo Dog Boots
# 9          Lazy Bonnezz LB1046-001 Pet Toy Box, Black
# 10  Dogit Nylon Training/Traffic Single Ply Dog Le...
# 11  DreamBone Beef Flavored Dog Chew Rawhide-Free ...
# 12  N-Bone Natural Puppy Teething Rings with DHA a...
# 13  Free Range Chicken Breast Wraps w/ Carrot Dog ...
# 14  Scattering Tubes Ash Urns 18-155&rdquo; Stock ...
# 15   PetSakes Pet Car Seat, 17 x 23 inch - Light Pink
# 16  WXBUY Adarl Cute Bowknot Lace Pet Dress Prince...
# 17  PetSafe Solvit Waterproof SUV Cargo Liner, Tru...
# 18       TropiClean Natural Alternative Dip with Neem
# 19           NFL Green Bay Packers 50&quot; Pet Leash
#
#                                           description
# 0   The Freedom Harness is "The Ferrari of Dog Wal...
# 1          Soft, Colorful Dog Sweatshirt MEDIUM - PNK
# 2   These natural steer muscles are braided and ro...
# 3   Warm acrylic knit sweater have a bright bow an...
# 4   If your dog has had fleas, theres a chance the...
# 5   <b>Summer is coming, and all kinds of mosquito...
# 6   Fantastic degreasing shampoo. Adds texture and...
# 7   ,Description<br> All you have to do is pop som...
# 8                                                 NaN
# 9   The simple yet stylish toy box will keep all o...
# 10  This dog leash offer a complete range of produ...
# 11  Chewing is an essential activity for dogs  it ...
# 12  Open a bag and indulge your 4-legged pal with ...
# 13  Formerly Free Range Dog Chews, now Free Range ...
# 14  Eco-Friendly Ash Tube. Pet Urns *Decomposed tu...
# 15  Our pet car seats are handmade with a special ...
# 16  <b>Size Table</b><br> <br> <b>Rhinestones Dres...
# 17  Keep your back seat clean with the PetSafe Sol...
# 18  Neem DIP is the NATURAL alternative to toxic i...
# 19           50 INCHES 3/4 INCHES WIDE NEW WITH TAGS.

# %% [markdown]
# The following cell defines a function that verifies that a DFTI category name appears either in the amazon categorization or the the product title.

# %%
def clean_txt(s):
    s = str(s).lower()
    c = "".join([x for x in s if x.isalpha() or x==" "])
    return c

def col_check(row, key, targets):
    result = 0
    
    for target in targets:
        if row[key].lower() in clean_txt(row[target]):
            result=1
    return result

def check_categorization(df, key, targets):
    df['check'] = df.apply(lambda row: col_check(row, key, targets), axis=1)    
    return df

# %% [markdown]
# The cell below picks 20 random products from each category, and then computes the accuracy for each.  The final results are displayed in a bar braph.

# %%
n = 20
accuracy = {}
full_checked = None
for idx, row in categories.iterrows():
    category = idx
    df = get_category_sample(category, n)
    checked_df = check_categorization(df, 'bcr_category', ['title','category'])
    if full_checked is None:
        full_checked = checked_df.copy()
    else:
        full_checked = pd.concat([full_checked, checked_df])

        
        
def save_cleaned_df(df):
    df['title'] = df.apply(lambda row: clean_txt(row['title']), axis=1)
    df['category'] = df.apply(lambda row: clean_txt(row['category']), axis=1)
    df['description'] = df.apply(lambda row: clean_txt(row['description']), axis=1)
    df.to_csv('Full_Checked_DF_Precheck.csv', index=False)
    
    
    
save_cleaned_df(full_checked)

print("Full Checked Saved.")
# Out:
# Full Checked Saved.

# %% [markdown]
# Unfortunately, due to the nature of the data, the check above is not 100% accurate.  As a result, the Full_Checked_DF_Precheck.csv file above was copied to Full_Check_DF.csv and then manually verified.  That file is loaded below, and the accuracy of the different categories are displayed on a barchart.

# %%
all_check_df = pd.read_csv('Full_Checked_DF.csv')
all_check_df
overall_weighted_accuracy = 0
accuracy = []
N = sum(categories['count'])
for idx, row in categories.iterrows():
    category = idx
    check_df = all_check_df[all_check_df['bcr_category']==category]
    acc = sum(check_df['check'])/len(check_df)
    cat_count = row['count']
    weighted = acc * cat_count/N
    accuracy.append(acc)
    overall_weighted_accuracy = overall_weighted_accuracy + weighted
    
plt.barh(categories.index, accuracy)
plt.title('Accuracy of First Level Categorization')
print("Overall Weighted Accuracy: {}".format(overall_weighted_accuracy))



# prod_df = prod_df.sample(50)


# new_df.columns=['asin', 'aws_title','amazon_cat', 'bcr_category']
# new_df.to_csv('category_check.csv')
# print("Done.")
# Out:
# Overall Weighted Accuracy: 0.7777272057465859
